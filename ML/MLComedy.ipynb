# %%
#import modules we need

import pandas
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import matplotlib.image as pltimg

# %%
#Data Setting
df = pandas.read_csv("shows.csv")
#Use map() to set numerical value to non-numerical value in the df {'UK': 0, 'USA': 1, 'N': 2}
d = {'UK': 0, 'USA': 1, 'N': 2}
df['Nationality'] = df['Nationality'].map(d)
d = {'YES': 1, 'NO': 0}
df['Go'] = df['Go'].map(d)


#feature columns : columns we try to predict from
features = ['Age', 'Experience', 'Rank', 'Nationality']
x = df[features]

#target column : column we try to predict
y = df['Go']

# %%
dtree = DecisionTreeClassifier()
dtree = dtree.fit(x, y)

#Make an image to observe
tree.plot_tree(dtree)
# Out:
# [Text(0.2857142857142857, 0.9, 'X[2] <= 6.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.14285714285714285, 0.7, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.42857142857142855, 0.7, 'X[2] <= 8.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.2857142857142857, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5714285714285714, 0.5, 'X[1] <= 9.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.42857142857142855, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7142857142857143, 0.3, 'X[0] <= 35.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5714285714285714, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8571428571428571, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
#Make a prediction
print(dtree.predict([[30.2, 10, 6, 1]])) #[0] is'No', [1] is Go
# Out:
# [0]
# c:\Users\patrick.s\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
